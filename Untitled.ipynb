# %%
import pandas as pd
import numpy as np
file = pd.read_csv('heart_attack_prediction_india.csv')
file.head()
# Out:
#    Patient_ID        State_Name  Age  Gender  Diabetes  Hypertension  Obesity  \
# 0           1         Rajasthan   42  Female         0             0        1
# 1           2  Himachal Pradesh   26    Male         0             0        0
# 2           3             Assam   78    Male         0             0        1
# 3           4            Odisha   58    Male         1             0        1
# 4           5         Karnataka   22    Male         0             0        0
#
#    Smoking  Alcohol_Consumption  Physical_Activity  ...  Diastolic_BP  \
# 0        1                    0                  0  ...           119
# 1        0                    1                  1  ...           115
# 2        0                    0                  1  ...           117
# 3        0                    0                  1  ...            65
# 4        0                    0                  1  ...           109
#
# ...

# %%
file.drop(columns=['Patient_ID'],inplace=True)

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Patient_ID               10000 non-null  int64
#  1   State_Name               10000 non-null  object
#  2   Age                      10000 non-null  int64
#  3   Gender                   10000 non-null  object
#  4   Diabetes                 10000 non-null  int64
#  5   Hypertension             10000 non-null  int64
#  6   Obesity                  10000 non-null  int64
#  7   Smoking                  10000 non-null  int64
#  8   Alcohol_Consumption      10000 non-null  int64
#  9   Physical_Activity        10000 non-null  int64
#  10  Diet_Score               10000 non-null  int64
#  11  Cholesterol_Level        10000 non-null  int64
#  12  Triglyceride_Level       10000 non-null  int64
#  13  LDL_Level                10000 non-null  int64
# ...

# %%
file.describe()
# Out:
#         Patient_ID           Age      Diabetes  Hypertension       Obesity  \
# count  10000.00000  10000.000000  10000.000000   10000.00000  10000.000000
# mean    5000.50000     49.394900      0.092900       0.24690      0.303700
# std     2886.89568     17.280301      0.290307       0.43123      0.459878
# min        1.00000     20.000000      0.000000       0.00000      0.000000
# 25%     2500.75000     35.000000      0.000000       0.00000      0.000000
# 50%     5000.50000     49.000000      0.000000       0.00000      0.000000
# 75%     7500.25000     64.000000      0.000000       0.00000      1.000000
# max    10000.00000     79.000000      1.000000       1.00000      1.000000
#
#             Smoking  Alcohol_Consumption  Physical_Activity    Diet_Score  \
# count  10000.000000         10000.000000       10000.000000  10000.000000
# mean       0.301400             0.352800           0.595800      5.021700
# ...

# %%
risk_percentage = file['Heart_Attack_Risk'].mean() * 100
print(f"Percentage of patients with heart attack risk: {risk_percentage:.2f}%")
# Out:
# Percentage of patients with heart attack risk: 30.07%

# %%
import seaborn as sns
state_risk = file.groupby('State_Name')['Heart_Attack_Risk'].mean().sort_values(ascending=False)
print("Heart Attack Risk by State:")
print(state_risk.head(10))
plt.figure(figsize=(10, 6))
top_states = state_risk.head(10)
sns.barplot(x=top_states.index, y=top_states.values)
plt.title('Top 10 States with Highest Heart Attack Risk')
plt.xticks(rotation=45)
plt.show()
# Out:
# Heart Attack Risk by State:
# State_Name
# Mizoram             0.357143
# Chhattisgarh        0.335840
# Himachal Pradesh    0.334294
# Maharashtra         0.334262
# Tamil Nadu          0.329513
# Kerala              0.323980
# Karnataka           0.314917
# Punjab              0.312312
# Madhya Pradesh      0.310345
# Andhra Pradesh      0.307018
# Name: Heart_Attack_Risk, dtype: float64

# %% [markdown]
# Analysing trend of heart attack risk among genders

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count occurrences instead of summing
female_counts = file[(file['Gender'] == 'Female') & (file['Heart_Attack_Risk'] == 1)].shape[0]
male_counts = file[(file['Gender'] == 'Male') & (file['Heart_Attack_Risk'] == 1)].shape[0]

# Dictionary to store counts
dic = {'Female': female_counts, 'Male': male_counts}

# Convert to DataFrame
df = pd.DataFrame.from_dict(dic, orient='index', columns=['Count'])

# Plot using a bar chart
df.plot(kind='bar', legend=False, color=['pink', 'blue'])

# Add labels
plt.xlabel("Gender")
plt.ylabel("Heart Attack Cases")
plt.title("Heart Attack Risk by Gender")
plt.xticks(rotation=0)  # Keep labels readable

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count cases with and without heart attack history
ha_counts_with_ha = file[(file['Heart_Attack_History'] == 1) & (file['Heart_Attack_Risk'] == 1)].shape[0]
ha_not_ha = file[(file['Heart_Attack_History'] == 0) & (file['Heart_Attack_Risk'] == 1)].shape[0]

# Create dictionary
dic2 = {'No History': ha_not_ha, 'History': ha_counts_with_ha}

# Convert to DataFrame
df1 = pd.DataFrame.from_dict(dic2, orient='index', columns=['Count'])

# Plot bar chart
df1.plot(kind='bar', legend=False, color=['red', 'green'])

# Labels
plt.xlabel("Heart Attack History")
plt.ylabel("Number of Cases")
plt.title("Heart Attack Risk Based on History")
plt.xticks(rotation=0)  # Keep labels horizontal

# Show plot
plt.show()

# %%
ha_with_diabetes = file[(file['Diabetes']==1)&(file['Heart_Attack_Risk']==1)].shape[0]
ha_without_diabetes = file[(file['Diabetes']==0)&(file['Heart_Attack_Risk']==1)].shape[0]
dic3 = {'diabetic':ha_with_diabetes,'not diabetic':ha_without_diabetes}
df2 = pd.DataFrame.from_dict(dic3,orient='index',columns=['Count'])
df2.plot(kind='bar',legend=False,color=['red','green'])
plt.xlabel('diabetes')
plt.ylabel('Risk of Heart attack')
plt.title('heart attack risk based on diabetes')
# Out:
# Text(0.5, 1.0, 'heart attack risk based on diabetes')

# %%
ha_with_diabetes = file[(file['Hypertension']==1)&(file['Heart_Attack_Risk']==1)].shape[0]
ha_without_diabetes = file[(file['Hypertension']==0)&(file['Heart_Attack_Risk']==1)].shape[0]
dic3 = {'has hypertension':ha_with_diabetes,'does not have':ha_without_diabetes}
df2 = pd.DataFrame.from_dict(dic3,orient='index',columns=['Count'])
df2.plot(kind='bar',legend=False,color=['red','green'])
plt.xlabel('hypertension')
plt.ylabel('Risk of Heart attack')
plt.title('analysis on basis of hypertension')
# Out:
# Text(0.5, 1.0, 'analysis on basis of hypertension')

# %%
ha_with_obesity = file[(file['Obesity']==1)&(file['Heart_Attack_Risk']==1)].shape[0]
ha_without_obesity = file[(file['Obesity']==0)&(file['Heart_Attack_Risk']==1)].shape[0]
dic3 = {'obese':ha_with_obesity,'fit':ha_without_obesity}
df2 = pd.DataFrame.from_dict(dic3,orient='index',columns=['Count'])
df2.plot(kind='bar',legend=False,color=['red','green'])
plt.xlabel('Obesity')
plt.ylabel('Risk of Heart attack')
plt.title('heart attack risk based on obesity')
# Out:
# Text(0.5, 1.0, 'heart attack risk based on obesity')

# %%
ha_with_smoking_habits = file[(file['Smoking']==1)&(file['Heart_Attack_Risk']==1)].shape[0]
ha_without_smoking_habits = file[(file['Smoking']==0)&(file['Heart_Attack_Risk']==1)].shape[0]
dic3 = {'suttebaaz':ha_with_smoking_habits,'seedha':ha_without_smoking_habits}
df2 = pd.DataFrame.from_dict(dic3,orient='index',columns=['Count'])
df2.plot(kind='bar',legend=False,color=['red','green'])
plt.xlabel('Obesity')
plt.ylabel('Risk of Heart attack')
plt.title('heart attack risk based on smoking habit')
# Out:
# Text(0.5, 1.0, 'heart attack risk based on smoking habit')

# %%
ha_with_healthy_habits = file[(file['Physical_Activity']==1)&(file['Heart_Attack_Risk']==1)].shape[0]
ha_without_healthy_habits = file[(file['Physical_Activity']==0)&(file['Heart_Attack_Risk']==1)].shape[0]
dic3 = {'does physical excercise':ha_with_healthy_habits,'does not':ha_without_healthy_habits}
df2 = pd.DataFrame.from_dict(dic3,orient='index',columns=['Count'])
df2.plot(kind='bar',legend=False,color=['red','green'])
plt.xlabel('Obesity')
plt.ylabel('Risk of Heart attack')
plt.title('heart attack risk based on physical activity')
# Out:
# Text(0.5, 1.0, 'heart attack risk based on physical activity')

# %%
plt.scatter(file['Stress_Level'],file['Heart_Attack_Risk'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count heart attack risk based on air pollution exposure
ha_with_good_air = file[(file['Air_Pollution_Exposure'] == 1) & (file['Heart_Attack_Risk'] == 1)].shape[0]
ha_without_good_air = file[(file['Air_Pollution_Exposure'] == 0) & (file['Heart_Attack_Risk'] == 1)].shape[0]

# Create dictionary
dic3 = {
    'Inhales Unhealthy Air': ha_without_good_air,
    'Inhales Good Quality Air': ha_with_good_air
}

# Convert to DataFrame
df2 = pd.DataFrame.from_dict(dic3, orient='index', columns=['Count'])

# Plot bar chart
df2.plot(kind='bar', legend=False, color=['red', 'green'])

# Correct labels
plt.xlabel('Air Pollution Exposure')  # Fixed label
plt.ylabel('Risk of Heart Attack')
plt.title('Analysis of Heart Attack Risk Based on Air Pollution Exposure')
plt.xticks(rotation=90)  # Rotate x-axis labels by 90 degrees

# Show plot
plt.show()

# %%
numerical_vars = ['Age', 'Diet_Score', 'Cholesterol_Level', 'Triglyceride_Level', 
                  'LDL_Level', 'HDL_Level', 'Systolic_BP', 'Diastolic_BP', 
                  'Air_Pollution_Exposure', 'Stress_Level', 'Emergency_Response_Time', 
                  'Annual_Income']
fig, axes = plt.subplots(3, 4, figsize=(20, 15))
axes = axes.flatten()
for i, var in enumerate(numerical_vars):
    sns.histplot(file[var], kde=True, ax=axes[i])
    axes[i].set_title(f'Distribution of {var}')
plt.tight_layout()
plt.show()

# %%
# Age group analysis
age_bins = pd.cut(file['Age'], bins=[0, 20, 30, 40, 50, 60, 70, 80], 
                  labels=['0-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80'])
risk_by_age = file.groupby(age_bins)['Heart_Attack_Risk'].mean()
plt.figure(figsize=(8, 5))
sns.barplot(x=risk_by_age.index, y=risk_by_age.values)
plt.title('Heart Attack Risk by Age Group')
plt.show()

# %%
# Correlation Analysis
corr_vars = [col for col in file.columns if col not in ['State_Name', 'Gender']]
corr_matrix = file[corr_vars].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# Pair Plot for Key Variables
key_vars = ['Age', 'Cholesterol_Level', 'Systolic_BP', 'Heart_Attack_Risk']
sns.pairplot(file[key_vars], hue='Heart_Attack_Risk')
plt.show()
